# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
#!pip install numpy
import numpy as np

# %%
np_arr = np.array([1,11,21,31,41,51])
type(np_arr)
# Out:
# numpy.ndarray

# %%
np_arr
# Out:
# array([ 1, 11, 21, 31, 41, 51])

# %%
np_arr[2]
# Out:
# np.int64(21)

# %%
np_arr.mean()
# Out:
# np.float64(26.0)

# %%
np.median(np_arr)
# Out:
# np.float64(26.0)

# %%
np_arr
# Out:
# array([ 1, 11, 21, 31, 41, 51])

# %%
np.sum(np_arr)
# Out:
# np.int64(156)

# %%
mean_v = np_arr.sum()/len(np_arr)

# %%
mean_v
# Out:
# np.float64(26.0)

# %%
from scipy import stats

stats.mode(np_arr)
# Out:
# ModeResult(mode=1, count=1)

# %%
import matplotlib.pyplot as plt

# Function to generate Fibonacci numbers
def fibonacci(n):
    fib_sequence = [0, 1]
    for i in range(2, n):
        fib_sequence.append(fib_sequence[-1] + fib_sequence[-2])
    return fib_sequence

# Generate the first 10 Fibonacci numbers
fib_numbers = fibonacci(10)

# Plotting
plt.figure(figsize=(10, 5))
plt.plot(fib_numbers, marker='o')
plt.title('First 10 Fibonacci Numbers')
plt.xlabel('Index')
plt.ylabel('Fibonacci Number')
plt.grid()
plt.show()
