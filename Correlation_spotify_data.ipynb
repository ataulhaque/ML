# %% [markdown]
# <a href="https://colab.research.google.com/github/ataulhaque/ML/blob/main/Correlation_spotify_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-66b8a07f-3c3e-4715-b496-cc77a2c39371" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-66b8a07f-3c3e-4715-b496-cc77a2c39371">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#load the csv data into dataset
import pandas as pd
spotify_sample = pd.read_csv('spotify_sample.csv')

# %%
#select only numeric columns
numeric_columns = spotify_sample.select_dtypes(include=['number'])
numeric_columns

#Calculate Pearson Correlation Matrix
correlation_matrix = numeric_columns.corr()

#Display the Correlation Matrix
correlation_matrix
# Out:
#                   danceability    energy       key  loudness      mode  \
# danceability          1.000000  0.141948  0.066452  0.240114 -0.141501
# energy                0.141948  1.000000  0.039179  0.730254  0.000358
# key                   0.066452  0.039179  1.000000  0.007292 -0.180481
# loudness              0.240114  0.730254  0.007292  1.000000 -0.032594
# mode                 -0.141501  0.000358 -0.180481 -0.032594  1.000000
# speechiness           0.168703  0.090992  0.006005  0.046749  0.043621
# acousticness         -0.266721 -0.513336 -0.025803 -0.438174  0.068691
# instrumentalness     -0.114022 -0.130986  0.056376 -0.287310  0.044735
# liveness             -0.061527  0.177326  0.003289  0.082682 -0.011751
# valence               0.391459  0.418949  0.024620  0.333334 -0.026595
# tempo                 0.057802  0.248902 -0.051931  0.203974  0.004053
# duration_ms          -0.225454 -0.045161 -0.040615 -0.039211  0.038411
# ...

# %% [markdown]
# # **Visualising Correlation Matrix**

# %%
#Visualize the correlation matrix using a heatmap
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# # **Visualising the relationship**

# %%
#Pairplot to visualize the relationship between 'danceability', 'energy', 'loudness', 'valence', 'liveness'
sns.pairplot(numeric_columns, vars=['danceability', 'energy', 'loudness', 'valence', 'liveness'])
plt.suptitle('Pairplot of Numeric Columns', y=1.02)
plt.legend(loc='upper right')
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
