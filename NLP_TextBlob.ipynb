# %% [markdown]
# <a href="https://colab.research.google.com/github/ataulhaque/ML/blob/main/NLP_TextBlob.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Import textblob
from textblob import TextBlob
import nltk
nltk.download('punkt')

sentence = "A Lazy Brown Fox jumps over the lazy dog"

blob = TextBlob(sentence)

print(blob.sentiment)
print(blob.sentiment.polarity)
print(blob.sentiment.subjectivity)
#print(blob.translate(to='hi'))
#print(blob.noun_phrases)
print(blob.words)
print(blob.sentences)
# Out:
# Sentiment(polarity=-0.25, subjectivity=1.0)
# -0.25
# 1.0
# ['A', 'Lazy', 'Brown', 'Fox', 'jumps', 'over', 'the', 'lazy', 'dog']
# [Sentence("A Lazy Brown Fox jumps over the lazy dog")]
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
for sentence in blob.sentences:
    print(sentence.sentiment)
# Out:
# Sentiment(polarity=-0.25, subjectivity=1.0)

# %%
spanish = translator.translate(sentence, target_lang="en-US")
print(spanish)

# %%
from textblob import Word
word = Word("theyr")
print(word.pluralize())
word.spellcheck()
# Out:
# theyrs
# [('they', 0.5713042216741622), ('their', 0.42869577832583783)]

# %%
sentence = TextBlob("Python is a high-level, general-purpose programming language.")
print(sentence.words)
print(sentence.words[4].singularize())
# Out:
# ['Python', 'is', 'a', 'high-level', 'general-purpose', 'programming', 'language']
# general-purpose

# %%
from pathlib import Path
import pandas as pd

blob = TextBlob(Path('RomeoAndJuliet.txt').read_text())
items = blob.word_counts.items()
items = [item for item in items if item[0].isalpha()]
items = [item for item in items if len(item[0]) > 3]
df = pd.DataFrame(items, columns=['Word', 'Count'])

# %%
df.sort_values(by='Count', ascending=False, inplace=True)
df.head(10).plot.bar(x='Word', y='Count', legend=False)
# Out:
# <Axes: xlabel='Word'>

# %%
text = Path('RomeoAndJuliet.txt').read_text()
blob = TextBlob(text)

# %%
import imageio
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
wordcloud = WordCloud(width=1000, height=1000, colormap='prism', background_color='white').generate(text)

# %%
from IPython.display import Image
plt.figure(figsize=(20,10), facecolor='k')
plt.imshow(wordcloud)
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()
